# %% [markdown]
# # Question 1:
# -Under package Gutenberg, see what files are in it.
# -Find out how many words and how many unique words in file 'austen-persuasion.txt'.
# -Calculate the frequency for each words and show the top 10 most frequent words and their frequency.
#  Try NOT to use FreqDist module.
# -Keep the punctuation and stop words in this question.

# %%
import nltk

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
string=nltk.corpus.gutenberg.words('austen-persuasion.txt')
print("Number of words in austen-persuasion.txt=",len(string))
# Out:
# Number of words in austen-persuasion.txt= 98171

# %%
emma = nltk.corpus.gutenberg.raw('austen-persuasion.txt')
words=emma.split()
uniqueWords=set(words)
print("Number of unique words in austen-persuasion.txt=",len(uniqueWords))
# Out:
# Number of unique words in austen-persuasion.txt= 10858

# %%
words=nltk.corpus.gutenberg.words('austen-persuasion.txt')

# %%
wordcount={}

for w in words:
    if w not in wordcount:
        wordcount[w] = 1
    else:
        wordcount[w] += 1

freq=sorted(wordcount.items())
freq
# Out:
# [('!', 253),
#  ('!"', 61),
#  ("!'", 2),
#  ('!--', 1),
#  ('"', 793),
#  ('&', 4),
#  ("'", 525),
#  ("'.", 1),
#  ('(', 69),
#  (')', 25),
#  ('),', 28),
#  (').', 1),
#  (');', 3),
#  (',', 6750),
#  (',"', 213),
#  (',"--', 1),
#  (',"--"', 1),
#  (",'", 11),
#  (',)', 5),
#  (',)--', 1),
#  (',--', 6),
#  (',--`', 1),
#  ('-', 308),
#  ('--', 104),
#  ('--!', 1),
#  ('--"', 10),
#  ('--(', 1),
#  ('---', 1),
#  ('---.', 1),
#  ('--;', 1),
#  ('.', 2741),
#  ('."', 369),
#  (".'", 7),
#  ('.\'"', 1),
#  ('.)', 4),
#  ('.,', 4),
#  ('.--', 1),
#  ('.--,', 1),
#  ('.--,"', 1),
#  ('1', 3),
#  ('10', 1),
#  ('11', 1),
#  ('12', 1),
#  ('13', 1),
#  ('14', 1),
#  ('15', 2),
#  ('16', 2),
#  ('17', 1),
#  ('1760', 1),
#  ('1784', 1),
#  ('1785', 1),
#  ('1787', 1),
#  ('1789', 1),
#  ('1791', 1),
#  ('18', 1),
#  ('1800', 1),
#  ('1803', 1),
#  ('1806', 1),
#  ('1810', 1),
#  ('1814', 1),
#  ('1818', 1),
#  ('19', 1),
#  ('1st', 1),
#  ('2', 1),
#  ('20', 2),
#  ('21', 1),
#  ('22', 1),
#  ('23', 1),
#  ('24', 1),
#  ('29th', 1),
#  ('3', 1),
#  ('4', 1),
#  ('5', 3),
#  ('6', 1),
#  ('7', 1),
#  ('8', 1),
#  ('9', 2),
#  (':', 124),
#  (':"', 1),
#  (':--', 3),
#  (':--"', 2),
#  (';', 1290),
#  (';"', 20),
#  (";'", 1),
#  (';)', 1),
#  (';--', 2),
#  (';--"', 1),
#  ('?', 122),
#  ('?"', 88),
#  ("?'", 4),
#  ('?\'"', 1),
#  ('?)', 1),
#  ('?),', 1),
#  ('A', 66),
#  ('About', 1),
#  ('Abydos', 1),
#  ('Accordingly', 1),
#  ('Admiral', 65),
#  ('Admiralty', 1),
#  ('After', 19),
#  ('Again', 1),
#  ('Ah', 9),
#  ('Alarming', 1),
#  ('Alas', 1),
#  ('Alicia', 2),
#  ('All', 13),
#  ('Allowances', 1),
#  ('Altered', 1),
#  ('Always', 1),
#  ('An', 7),
#  ('And', 62),
#  ('Anne', 497),
#  ('Another', 4),
#  ('Anxious', 1),
#  ('Any', 1),
#  ('Anybody', 1),
#  ('Anything', 1),
#  ('Archibald', 2),
#  ('Are', 5),
#  ('As', 22),
#  ('Asp', 6),
#  ('At', 14),
#  ('Atkinson', 1),
#  ('Atlantic', 1),
#  ('August', 2),
#  ('Austen', 1),
#  ('Ay', 6),
#  ('Aye', 1),
#  ('Bahama', 1),
#  ('Baldwin', 4),
#  ('Baronet', 1),
#  ('Baronetage', 2),
#  ('Basil', 3),
#  ('Bath', 99),
#  ('Be', 1),
#  ('Because', 1),
#  ('Before', 3),
#  ('Believe', 1),
#  ('Belmont', 3),
#  ('Benwick', 70),
#  ('Bermuda', 1),
#  ('Between', 2),
#  ('Birth', 1),
#  ('Bishop', 1),
#  ('Bless', 5),
#  ('Bond', 1),
#  ('Both', 2),
#  ('Brand', 1),
#  ('Breakfast', 1),
#  ('Bride', 1),
#  ('Bridge', 1),
#  ('Brigden', 2),
#  ('Buildings', 12),
#  ('But', 111),
#  ('By', 7),
#  ('Byron', 3),
#  ('Call', 1),
#  ('Camden', 29),
#  ('Came', 1),
#  ('Can', 7),
#  ('Cape', 3),
#  ('Captain', 297),
#  ('Captains', 2),
#  ('Carteret', 12),
#  ('Certainly', 4),
#  ('Chapter', 24),
#  ('Charles', 166),
#  ('Charmouth', 2),
#  ('Cheshire', 1),
#  ('Christian', 3),
#  ('Christmas', 6),
#  ('Clay', 66),
#  ('Clifton', 1),
#  ('Cobb', 14),
#  ('Colonel', 23),
#  ('Come', 3),
#  ('Commons', 1),
#  ('Concert', 3),
#  ('Consider', 1),
#  ('Cork', 1),
#  ('Cottage', 16),
#  ('Could', 7),
#  ('Cousin', 1),
#  ('Crescent', 1),
#  ('Crewkherne', 2),
#  ('Croft', 58),
#  ('Crofts', 24),
#  ('Dalrymple', 28),
#  ('Dalrymples', 4),
#  ('Dare', 2),
#  ('Deal', 2),
#  ('Dear', 7),
#  ('December', 1),
#  ('Depend', 4),
#  ('Dick', 6),
#  ('Did', 5),
#  ('Do', 20),
#  ('Does', 3),
#  ('Domingo', 1),
#  ('Don', 2),
#  ('Dorsetshire', 1),
#  ('Doubtless', 1),
#  ('Dowager', 3),
#  ('Dr', 10),
#  ('Drew', 1),
#  ('Dugdale', 1),
#  ('Durands', 1),
#  ('E', 1),
#  ('ELLIOT', 1),
#  ('Each', 2),
#  ('East', 2),
#  ('Education', 1),
#  ('Edward', 5),
#  ('Eight', 2),
#  ('Either', 2),
#  ('Elegance', 1),
#  ('Elizabeth', 89),
#  ('Elizabeths', 1),
#  ('Elliot', 288),
#  ('Elliots', 6),
#  ('Emma', 1),
#  ('End', 1),
#  ('England', 6),
#  ('English', 3),
#  ('Esq', 5),
#  ('Even', 4),
#  ('Events', 1),
#  ('Every', 6),
#  ('Everybody', 5),
#  ('Everything', 5),
#  ('Exactly', 1),
#  ('Excellent', 1),
#  ('Excepting', 1),
#  ('Exeter', 1),
#  ('F', 1),
#  ('Facts', 2),
#  ('Family', 1),
#  ('Fanny', 4),
#  ('February', 2),
#  ('Few', 1),
#  ('Finis', 1),
#  ('First', 1),
#  ('For', 12),
#  ('Fortune', 1),
#  ('Forty', 2),
#  ('Four', 1),
#  ('Frankland', 1),
#  ('Freckles', 1),
#  ('Frederick', 23),
#  ('French', 2),
#  ('Friday', 1),
#  ('From', 5),
#  ('Gay', 2),
#  ('German', 1),
#  ('Get', 1),
#  ('Giaour', 2),
#  ('Gibraltar', 3),
#  ('Give', 2),
#  ('Gloucester', 1),
#  ('Glowing', 1),
#  ('Go', 1),
#  ('God', 9),
#  ('Good', 6),
#  ('Gout', 1),
#  ('Governor', 1),
#  ('Gowland', 3),
#  ('Granting', 1),
#  ('Grappler', 3),
#  ('Great', 14),
#  ('Grierson', 1),
#  ('HALL', 1),
#  ('Ha', 2),
#  ('Had', 9),
#  ('Half', 2),
#  ('Hall', 27),
#  ('Hamilton', 4),
#  ('Happily', 1),
#  ('Happy', 1),
#  ('Hardly', 1),
#  ('Harry', 1),
#  ('Hart', 3),
#  ('Harville', 75),
#  ('Harvilles', 18),
#  ('Have', 6),
#  ('Having', 2),
#  ('Hayter', 38),
#  ('Hayters', 5),
#  ('He', 225),
#  ('Hear', 1),
#  ('Heaven', 4),
#  ('Heir', 2),
#  ('Henrietta', 74),
#  ('Henry', 2),
#  ('Her', 45),
#  ('Here', 16),
#  ('Hers', 1),
#  ('Herself', 1),
#  ('His', 34),
#  ('Hitherto', 1),
#  ('Honourable', 2),
#  ('House', 16),
#  ('How', 37),
#  ('However', 6),
#  ('Husbands', 1),
#  ('I', 1124),
#  ('II', 1),
#  ('Ibbotsons', 1),
#  ('If', 40),
#  ('Immediately', 1),
#  ('In', 43),
#  ('Indeed', 11),
#  ('Indies', 7),
#  ('Instead', 2),
#  ('Intimately', 1),
#  ('Ireland', 2),
#  ('Irish', 2),
#  ('Is', 5),
#  ('Islands', 1),
#  ('Isle', 1),
#  ('It', 181),
#  ('Italian', 5),
#  ('Ives', 2),
#  ('James', 6),
#  ('Jane', 1),
#  ('January', 1),
#  ('Jealousy', 2),
#  ('Jemima', 4),
#  ('John', 2),
#  ('Journeys', 1),
#  ('July', 2),
#  ('June', 3),
#  ('Just', 1),
#  ('KELLYNCH', 1),
#  ('Kellynch', 72),
#  ('Kindest', 1),
#  ('Knowing', 1),
#  ('Known', 1),
#  ('Laconia', 8),
#  ('Lady', 191),
#  ('Lake', 1),
#  ('Lansdown', 1),
#  ('Larolles', 2),
#  ('Laura', 7),
#  ('Leave', 2),
#  ('Lessening', 1),
#  ('Let', 5),
#  ('Like', 1),
#  ('Lisbon', 2),
#  ('List', 1),
#  ('Little', 1),
#  ('Lodge', 5),
#  ('London', 14),
#  ('Look', 2),
#  ('Lord', 8),
#  ('Louisa', 111),
#  ('Louise', 1),
#  ('Lower', 1),
#  ('Lucky', 2),
#  ('Lyme', 67),
#  ('M', 1),
#  ('Mackenzie', 1),
#  ('Maclean', 1),
#  ('Make', 1),
#  ('Man', 1),
#  ('Mansion', 4),
#  ('Many', 2),
#  ('March', 1),
#  ('Mark', 1),
#  ('Market', 1),
#  ('Marlborough', 5),
#  ('Marmion', 1),
#  ('Married', 1),
#  ('Mary', 138),
#  ('Marys', 1),
#  ('Master', 1),
#  ('Materials', 1),
#  ('Mediterranean', 1),
#  ('Men', 1),
#  ('Merely', 1),
#  ('Michaelmas', 3),
#  ('Milsom', 5),
#  ('Minehead', 1),
#  ('Miss', 123),
#  ('Modest', 1),
#  ('Molland', 1),
#  ('Monday', 3),
#  ('Money', 2),
#  ('Monkford', 8),
#  ('More', 4),
#  ('Morley', 1),
#  ('Morning', 1),
#  ('Most', 1),
#  ('Mr', 256),
#  ('Mrs', 291),
#  ('Musgrove', 130),
#  ('Musgroves', 41),
#  ('Mutual', 1),
#  ('My', 29),
#  ('Nation', 1),
#  ('Navy', 1),
#  ('Nay', 4),
#  ('Neither', 4),
#  ('Never', 2),
#  ('Next', 1),
#  ('Ninety', 1),
#  ('No', 47),
#  ('Nobody', 5),
#  ('None', 1),
#  ('North', 4),
#  ('Not', 8),
#  ('Nothing', 8),
#  ('November', 9),
#  ('Now', 14),
#  ('Nurse', 3),
#  ('Nursing', 1),
#  ('OF', 1),
#  ('Octagon', 3),
#  ('Of', 5),
#  ('Oh', 53),
#  ('Old', 4),
#  ('On', 10),
#  ('Once', 5),
#  ('One', 17),
#  ('Only', 5),
#  ('Other', 1),
#  ('Our', 3),
#  ('Pardon', 1),
#  ('Park', 2),
#  ('Penelope', 2),
#  ('Perhaps', 7),
#  ('Personal', 1),
#  ('Persuasion', 1),
#  ('Phoo', 2),
#  ('Picture', 1),
#  ('Pinny', 1),
#  ('Pity', 1),
#  ('Place', 37),
#  ('Plymouth', 7),
#  ('Pooles', 1),
#  ('Poor', 7),
#  ('Portsmouth', 3),
#  ('Pray', 6),
#  ('Precisely', 1),
#  ('Presently', 1),
#  ('Prettier', 1),
#  ('Pretty', 1),
#  ('Principal', 1),
#  ('Promising', 1),
#  ('Providence', 3),
#  ('Pulteney', 1),
#  ('Pump', 2),
#  ('Putting', 1),
#  ('Queen', 1),
#  ('Quit', 1),
#  ('Quite', 2),
#  ('Reported', 1),
#  ('Richard', 5),
#  ('Rivers', 4),
#  ('Robinson', 3),
#  ('Rooke', 7),
#  ('Room', 7),
#  ('Rub', 1),
#  ('Russell', 148),
#  ('Sailors', 1),
#  ('Sarah', 2),
#  ('Saturday', 1),
#  ('Scenes', 1),
#  ('Scheherazade', 1),
#  ('Scott', 2),
#  ('Seas', 1),
#  ('September', 4),
#  ('Shabby', 1),
#  ('Shall', 2),
#  ('She', 327),
#  ('Shepherd', 31),
#  ('Shirley', 11),
#  ('Shocked', 1),
#  ('Should', 3),
#  ('Shropshire', 3),
#  ('Sidmouth', 1),
#  ('Since', 2),
#  ('Sir', 144),
#  ('Situated', 1),
#  ('Six', 1),
#  ('Sixty', 1),
#  ('Smith', 68),
#  ('Smiths', 2),
#  ('So', 21),
#  ('Soldiers', 1),
#  ('Some', 1),
#  ('Somerset', 2),
#  ('Somersetshire', 4),
#  ('Something', 3),
#  ('Songs', 1),
#  ('Soon', 1),
#  ('Sophia', 2),
#  ('Sophy', 6),
#  ('Sophys', 1),
#  ('Sound', 1),
#  ('South', 1),
#  ('Speed', 1),
#  ('Spicers', 1),
#  ('Squares', 1),
#  ('St', 3),
#  ('Stevenson', 1),
#  ('Still', 2),
#  ('Strafford', 1),
#  ('Strangers', 1),
#  ('Street', 18),
#  ('Streights', 1),
#  ('Such', 15),
#  ('Sultaness', 1),
#  ('Sunday', 2),
#  ('Sundays', 1),
#  ('Suppose', 1),
#  ('Surely', 2),
#  ('Surprise', 1),
#  ('Take', 1),
#  ('Talks', 1),
#  ('Tattersall', 1),
#  ('Taunton', 6),
#  ('Tell', 2),
#  ('Temple', 1),
#  ('Ten', 1),
#  ('Thames', 1),
#  ('Thank', 4),
#  ('That', 29),
#  ('The', 209),
#  ('Their', 20),
#  ('Then', 10),
#  ('There', 70),
#  ('Therefore', 1),
#  ('These', 9),
#  ('They', 110),
#  ('Thirteen', 3),
#  ('This', 50),
#  ('Thornberry', 2),
#  ('Those', 1),
#  ('Though', 10),
#  ('Three', 2),
#  ('Thursday', 3),
#  ('Thus', 1),
#  ('Till', 2),
#  ('Time', 1),
#  ('To', 33),
#  ('Too', 1),
#  ('Towards', 1),
#  ('Trafalgar', 1),
#  ('Trent', 1),
#  ('Troubles', 1),
#  ('True', 3),
#  ('Tuesday', 5),
#  ('Tunbridge', 1),
#  ('Twelve', 2),
#  ('Two', 2),
#  ('Unintentionally', 1),
#  ('Union', 3),
#  ('Unjust', 1),
#  ('Up', 1),
#  ('Upon', 8),
#  ('Uppercross', 77),
#  ('Vague', 1),
#  ('Vanity', 1),
#  ('Various', 1),
#  ('Very', 9),
#  ('Viscountess', 4),
#  ('W', 2),
#  ('Wallis', 34),
#  ('Wallises', 2),
#  ('Walter', 141),
#  ('Warmth', 1),
#  ('Was', 7),
#  ('We', 45),
#  ('Wednesday', 1),
#  ('Well', 22),
#  ('Wells', 1),
#  ('Wentworth', 218),
#  ('West', 5),
#  ('Western', 1),
#  ('Westgate', 7),
#  ('What', 25),
#  ('When', 32),
#  ('Where', 5),
#  ('Whether', 2),
#  ('Which', 1),
#  ('While', 11),
#  ('White', 3),
#  ('Who', 4),
#  ('Whoever', 1),
#  ('Why', 5),
#  ('Wight', 1),
#  ('Will', 5),
#  ('William', 4),
#  ('Winthrop', 11),
#  ('With', 11),
#  ('Within', 1),
#  ('Without', 2),
#  ('Wm', 1),
#  ('Women', 2),
#  ('Worse', 1),
#  ('Would', 4),
#  ('Yard', 1),
#  ('Yarmouth', 3),
#  ('Yes', 34),
#  ('Yet', 3),
#  ('You', 80),
#  ('Young', 1),
#  ('Your', 12),
#  ('Yours', 1),
#  ('Z', 1),
#  ('[', 1),
#  (']', 1),
#  ('`', 29),
#  ('a', 1529),
#  ('abbreviation', 1),
#  ('abdication', 1),
#  ('abide', 1),
#  ('abilities', 3),
#  ('able', 30),
#  ('abode', 1),
#  ('abominable', 1),
#  ('abominate', 1),
#  ('abominates', 1),
#  ('about', 96),
#  ('above', 6),
#  ('abroad', 5),
#  ('absence', 9),
#  ('absent', 4),
#  ('absenting', 1),
#  ('absolute', 3),
#  ('absolutely', 5),
#  ('abstraction', 1),
#  ('absurd', 6),
#  ('absurdity', 1),
#  ('abundance', 1),
#  ('abuse', 1),
#  ('abused', 2),
#  ('accent', 1),
#  ('accept', 6),
#  ('acceptable', 2),
#  ('acceptance', 1),
#  ('accepted', 3),
#  ('accepting', 3),
#  ('accession', 1),
#  ('accessions', 1),
#  ('accident', 7),
#  ('accidental', 1),
#  ('accidentally', 2),
#  ('accommodate', 2),
#  ('accommodating', 1),
#  ('accommodation', 3),
#  ('accommodations', 6),
#  ('accompanied', 1),
#  ('accompany', 1),
#  ('accompanying', 1),
#  ('accomplish', 2),
#  ('accomplished', 2),
#  ('accomplishment', 1),
#  ('accomplishments', 4),
#  ('accord', 1),
#  ('according', 1),
#  ('accordingly', 5),
#  ('accosted', 1),
#  ('account', 37),
#  ('accounts', 5),
#  ('accurately', 1),
#  ('accuse', 1),
#  ('accused', 1),
#  ('accustomary', 1),
#  ('acknowledge', 8),
#  ('acknowledged', 8),
#  ('acknowledgement', 2),
#  ('acknowledgements', 1),
#  ('acquaintance', 61),
#  ('acquainted', 27),
#  ('acquiescence', 2),
#  ('acquired', 4),
#  ('acquisition', 1),
#  ('acquittal', 1),
#  ('acquitted', 1),
#  ('acre', 1),
#  ('acres', 1),
#  ('across', 3),
#  ('act', 8),
#  ('acted', 2),
#  ('acting', 5),
#  ('action', 2),
#  ('actions', 2),
#  ('active', 5),
#  ('activity', 2),
#  ('actual', 4),
#  ('actually', 10),
#  ('actuated', 1),
#  ('acute', 1),
#  ('adapted', 1),
#  ('add', 6),
#  ('added', 24),
#  ('adding', 4),
#  ('addition', 5),
#  ('additional', 3),
#  ('address', 2),
#  ('addressed', 3),
#  ('addresses', 3),
#  ('addressing', 3),
#  ('adieu', 1),
#  ('adieus', 1),
#  ('adjoining', 3),
#  ('admirably', 1),
#  ('admiral', 4),
#  ('admiration', 10),
#  ('admire', 7),
#  ('admired', 5),
#  ('admirer', 1),
#  ('admires', 1),
#  ('admiring', 3),
#  ('admit', 9),
#  ('admitted', 13),
#  ('adopt', 1),
#  ('adopted', 3),
#  ('advance', 1),
#  ('advanced', 1),
#  ('advancing', 1),
#  ('advantage', 22),
#  ('advantages', 5),
#  ('adverse', 1),
#  ('advertise', 1),
#  ('advertised', 1),
#  ('advice', 5),
#  ('advisable', 1),
#  ('advise', 1),
#  ('advised', 2),
#  ('advising', 2),
#  ('affairs', 8),
#  ('affect', 2),
#  ('affected', 10),
#  ('affecting', 1),
#  ('affection', 9),
#  ('affectionate', 3),
#  ('affectionately', 3),
#  ('affections', 3),
#  ('afflicted', 3),
#  ('affliction', 3),
#  ('affluence', 3),
#  ('affluent', 1),
#  ('afford', 9),
#  ('afforded', 2),
#  ('affords', 1),
#  ('affront', 1),
#  ('affronted', 1),
#  ('affronts', 1),
#  ('afloat', 1),
#  ('afraid', 15),
#  ('after', 77),
#  ('afternoon', 3),
#  ('afterwards', 36),
#  ('again', 131),
#  ('against', 27),
#  ('againsts', 1),
#  ('age', 11),
#  ('agent', 1),
#  ('aggravation', 3),
#  ('agitated', 3),
#  ('agitation', 14),
#  ('agitations', 4),
#  ('ago', 16),
#  ('agony', 6),
#  ('agree', 7),
#  ('agreeable', 38),
#  ('agreed', 15),
#  ('agreeing', 1),
#  ('agreement', 2),
#  ('aid', 2),
#  ('ailed', 1),
#  ('ailments', 1),
#  ('air', 20),
#  ('airs', 1),
#  ('akin', 1),
#  ('alacrity', 4),
#  ('alarm', 6),
#  ('alarmed', 4),
#  ('alarming', 3),
#  ('alas', 4),
#  ('alertness', 1),
#  ('alienable', 1),
#  ('alienations', 1),
#  ('alike', 4),
#  ('alive', 4),
#  ('all', 517),
#  ('allayed', 1),
#  ('alliance', 5),
#  ('alliances', 1),
#  ('allow', 9),
#  ('allowable', 1),
#  ('allowance', 3),
#  ('allowances', 1),
#  ('allowed', 15),
#  ('allowing', 1),
#  ('alloy', 3),
#  ('alluded', 3),
#  ('allusion', 1),
#  ('allusions', 1),
#  ('almost', 60),
#  ('alone', 21),
#  ('along', 13),
#  ('aloud', 2),
#  ('already', 20),
#  ('also', 18),
#  ('alter', 3),
#  ('alteration', 2),
#  ('alterations', 1),
#  ('altered', 11),
#  ('altering', 1),
#  ('alternation', 1),
#  ('alternatives', 1),
#  ('altogether', 13),
#  ('always', 109),
#  ('am', 137),
#  ('amazement', 2),
#  ('amazingly', 1),
#  ('ambition', 1),
#  ('ambitious', 1),
#  ('amendment', 1),
#  ('amends', 1),
#  ('amiable', 7),
#  ('amicable', 1),
#  ('amidst', 3),
#  ('amiss', 3),
#  ('among', 39),
#  ('amongst', 3),
#  ('amount', 1),
#  ('ample', 2),
#  ('amuse', 2),
#  ('amused', 6),
#  ('amusement', 10),
#  ('amusements', 1),
#  ('amusing', 3),
#  ('an', 238),
#  ('analogy', 3),
#  ('ancestry', 1),
#  ('anchorage', 1),
#  ('ancient', 3),
#  ('and', 2739),
#  ('anecdotes', 1),
#  ('anew', 2),
#  ('anger', 2),
#  ('angry', 5),
#  ('anguish', 1),
#  ('animate', 3),
#  ('animated', 4),
#  ('animation', 5),
#  ('annexed', 1),
#  ('announce', 2),
#  ('announced', 4),
#  ('annual', 1),
#  ('another', 62),
#  ('answer', 31),
#  ('answered', 15),
#  ('answers', 3),
#  ('anticipate', 1),
#  ('anticipated', 2),
#  ('anticipating', 2),
#  ('anticipation', 1),
#  ('anxieties', 1),
#  ('anxiety', 11),
#  ('anxious', 17),
#  ('anxiously', 4),
#  ('any', 198),
#  ('anybody', 20),
#  ('anyone', 1),
#  ('anything', 48),
#  ('anywhere', 9),
#  ('apace', 2),
#  ('apart', 1),
#  ('apartment', 2),
#  ('apartments', 2),
#  ('apologies', 3),
#  ('apologised', 1),
#  ('apologize', 2),
#  ('apology', 5),
#  ('apothecary', 2),
#  ('apparent', 7),
#  ('apparently', 6),
#  ('appeal', 4),
#  ('appealed', 2),
#  ('appear', 13),
#  ('appearance', 24),
#  ('appearances', 2),
#  ('appeared', 20),
#  ('appearing', 3),
#  ('appears', 3),
#  ('appeased', 1),
#  ('apples', 1),
#  ('applicant', 1),
#  ('application', 4),
#  ('applications', 4),
#  ('applied', 5),
#  ('apply', 2),
#  ('applying', 2),
#  ('appointed', 3),
#  ('appointment', 5),
#  ('appreciate', 1),
#  ('appreciation', 1),
#  ('apprehend', 2),
#  ('apprehension', 2),
#  ('apprehensions', 3),
#  ('apprehensive', 1),
#  ('approach', 5),
#  ('approachable', 1),
#  ('approached', 3),
#  ('approaching', 1),
#  ('approve', 1),
#  ('approved', 2),
#  ('approves', 1),
#  ('approving', 1),
#  ('apt', 3),
#  ('arch', 2),
#  ('archly', 1),
#  ('ardent', 1),
#  ('ardour', 3),
#  ('are', 141),
#  ('arguing', 1),
#  ('argument', 2),
#  ('arise', 1),
#  ('arising', 2),
#  ('aristocratic', 1),
#  ('arm', 11),
#  ('armed', 1),
#  ('arms', 8),
#  ('arose', 4),
#  ('around', 12),
#  ('arrange', 2),
#  ('arranged', 6),
#  ('arrangement', 5),
#  ('arrangements', 6),
#  ('arranger', 1),
#  ('arranging', 1),
#  ('arrival', 9),
#  ('arrive', 4),
#  ('arrived', 9),
#  ('arriving', 3),
#  ('art', 3),
#  ('artful', 2),
#  ('article', 4),
#  ('articles', 2),
#  ('artificial', 4),
#  ('artist', 1),
#  ('as', 787),
#  ('ascended', 1),
#  ('ascending', 1),
#  ('ascent', 2),
#  ('ascertain', 4),
#  ('ascertained', 3),
#  ('ascertaining', 2),
#  ('ashamed', 14),
#  ('ashore', 2),
#  ('aside', 2),
#  ('ask', 10),
#  ('asked', 26),
#  ('asking', 4),
#  ('aspect', 1),
#  ('assembled', 1),
#  ('assenting', 1),
#  ('assert', 1),
#  ('asserted', 2),
#  ('assertion', 2),
#  ('assiduous', 2),
#  ('assiduously', 1),
#  ('assist', 5),
#  ('assistance', 6),
#  ('assistant', 1),
#  ('assistants', 1),
#  ('assisted', 5),
#  ('assisting', 2),
#  ('assizes', 1),
#  ('associate', 1),
#  ('associated', 1),
#  ('associates', 1),
#  ('association', 1),
#  ('associations', 2),
#  ('assorting', 1),
#  ('assuage', 1),
#  ('assume', 1),
#  ('assumed', 1),
#  ('assuming', 1),
#  ('assurances', 1),
#  ('assure', 25),
#  ('assured', 5),
#  ('assuring', 1),
#  ('astonish', 1),
#  ('astonished', 8),
#  ('astonishing', 1),
#  ('astonishment', 10),
#  ('astray', 1),
#  ('asunder', 3),
#  ('at', 519),
#  ('ate', 1),
#  ('atmosphere', 1),
#  ('atonement', 1),
#  ('attach', 4),
#  ('attached', 5),
#  ...]

# %%
wordSort=sorted(wordcount.items(), key=lambda x: x[1], reverse=True)
print("Top 10 words with frequencies are: ")
wordSort[:10]
# Out:
# Top 10 words with frequencies are:
# [(',', 6750),
#  ('the', 3120),
#  ('to', 2775),
#  ('.', 2741),
#  ('and', 2739),
#  ('of', 2564),
#  ('a', 1529),
#  ('in', 1346),
#  ('was', 1330),
#  (';', 1290)]
